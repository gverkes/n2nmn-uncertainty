# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
A = np.load("../NO_TRI_IMG_0_NO_TRI_QST_0/train.large.input.npy")

# %%
for i in range(10):
    plt.imshow(A[np.random.randint(1000)])
    plt.show()
